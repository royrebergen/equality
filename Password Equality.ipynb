# %% [markdown]
# ![alttext](keyboard.jpg "Left/Right keyboard")

# %%
import pandas as pd
import re

# %%
'''Config'''
keys = { 'l_keys':['q','w','e','r','t','a','s','d','f','g','z','x','c','v'],
         'r_keys':['y','u','i','o','p','h','j','k','l','b','n','m']}

# %%
'''Functions'''
def cleaning(row):
    x = re.sub(r'\W+', '', row['word'])
    return pd.Series({'length': len(x),'word_clean': x})

def sideLen(row):
    '''
    Count the number of characters on both sides of the keyboard
    '''
    global keys
    x = row['word_clean'].lower()
    
    # left & right count
    l_count = 0
    r_count = 0
    
    for y in x:
        if y in keys['l_keys']:
            l_count += 1
        elif y in keys['r_keys']:
            r_count += 1
            
    return pd.Series({'l_count':l_count,
                      'l_per':(round((l_count/len(x))*100)),
                      'r_count':r_count,
                      'r_per':(round((r_count/len(x))*100))})

# %%
'''Load the data'''
if 'df' not in locals():
    df = pd.read_csv('data/woordenlijst.txt', sep="\n", header=None)
    df.columns = ["word"]
    df[['length','word_clean']] = df.apply(lambda row: cleaning(row), axis=1)

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# cleaning   function     <function cleaning at 0x7f267db1ed90>
# df         DataFrame                             <...>[164313 rows x 3 columns]
# f          function     <function f at 0x7f267dec1378>
# pd         module       <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# r          function     <function r at 0x7f267dec1400>
# re         module       <module 're' from '/opt/c<...>nda/lib/python3.6/re.py'>
# sideLen    function     <function sideLen at 0x7f267dec1488>

# %%
df[['l_count','l_per','r_count','r_per']] = df.apply(lambda row: sideLen(row),axis=1)

# %%
df.head()
# Out:
#               word  length     word_clean  l_count  l_per  r_count  r_per
# 0  's anderendaags      13  sanderendaags       11     85        2     15
# 1        's avonds       7        savonds        5     71        2     29
# 2       's middags       8       smiddags        6     75        2     25
# 3        's nachts       7        snachts        5     71        2     29
# 4      's ochtends       9      sochtends        6     67        3     33

# %%
df[(df.r_per == 50) & (df.l_per == 50)]
# Out:
#                           word  length              word_clean  l_count  \
# 26                   ADHD-kind       8                ADHDkind        4
# 29                        AMvB       4                    AMvB        2
# 31               AOV-uitkering      12            AOVuitkering        6
# 35               AOW-uitkering      12            AOWuitkering        6
# 36                        AROB       4                    AROB        2
# 48                  Aborigines      10              Aborigines        5
# 50                      Adonai       6                  Adonai        3
# 69                    Algerijn       8                Algerijn        4
# 74          Allerheiligenvloed      18      Allerheiligenvloed        9
# 82                    Amazonen       8                Amazonen        4
# 83                    Ambonees       8                Ambonees        4
# 84           American football      16        Americanfootball        8
# ...

# %%
df.to_csv('list.csv')

# %% [markdown]
# ![alttext](powerBi.PNG "Dashboard")
