# %%
![alttext](keyboard.jpg "Left/Right keyboard")

# %%
import pandas as pd
import re

# %%
'''Config'''
keys = { 'left_characters':['1','2','3','4','5','6','q','w','e','r','t','a','s','d','f','g','z','x','c','v'],
         'right_characters':['7','8','9','0','y','u','i','o','p','h','j','k','l','b','n','m']}

# %%
def clean_word(row):
    """Remove all non-alphanumeric characters in a word
    
    Keyword arguments:
    row -- a pandas DataFrame row, index key 'word' is used
    
    Returns: a Pandas Series object containing the clean word an its length
    """
    x = re.sub(r'\W+', '', row['word'])
    return pd.Series({'length': len(x),'word_clean': x})

def characters_per_side(row):
    """Count the amount of characters per keyboard side in a word
    
    Keyword arguments:
    row -- a pandas DataFrame row, index key 'word_clean' is used
    
    Returns: a Pandas Series object containing the numer of characters on both sides and there relative values
    """
    global keys
    x = row['word_clean'].lower()
    
    l_count = 0
    r_count = 0
    
    for y in x:
        if y in keys['left_characters']:
            l_count += 1
        elif y in keys['right_characters']:
            r_count += 1
            
    return pd.Series({'l_count':l_count,
                      'l_per':(round((l_count/len(x))*100)),
                      'r_count':r_count,
                      'r_per':(round((r_count/len(x))*100))})


def sequance_score(row):
    word = row['word_clean'].lower()
    penalty = 0
    last_known_position = ''
    for index, char in enumerate(word):
        if index == 0:
            if char in keys['left_characters']:
                last_known_position = 0
            if char in keys['right_characters']:
                last_known_position = 1
            continue
        if char in keys['left_characters']:
            if last_known_position == 0:
                penalty+=1
            last_known_position = 0;
        else:
            if last_known_position == 1:
                penalty+=1
            last_known_position = 1
    return pd.Series({'penalty':penalty})

# %% [markdown]
# '''
# b rechts
# a links
# a links
# n rechts
#
# 0 (b) en 2 (a) zijn even
# 1 (a) en 3 (n) zijn oneven
#
#
# L_keys  = 2
# R_keys = 2
# '''
# word = 'baan'
#
# even = word[::2]         # even  - start at the beginning at take every second item
# odd = word[1::2]        # odd - start at second item and take every second item
#
# start = 'l_keys'
# if even[0] in keys['r_keys']:
#     start = 'r_keys'
#
# c = sum(el not in keys[start] for el in even)
# e = sum(el in keys[start] for el in odd)
# print(c + e)

# %%
'''Load the data'''
if 'df' not in locals():
    df = pd.read_csv('data/woordenlijst.txt', sep="\n", header=None)
    df.columns = ["word"]
    df[['length','word_clean']] = df.apply(lambda row: clean_word(row), axis=1)

# %%
whos
# Out:
# Variable        Type        Data/Info
# -------------------------------------
# clean_word      function    <function clean_word at 0x7fc7903c9488>
# cleaning        function    <function cleaning at 0x7fc7903c9268>
# sequanceScore   function    <function sequanceScore at 0x7fc79040fea0>
# sideLen         function    <function sideLen at 0x7fc79040fd90>

# %%
df[['l_count','l_per','r_count','r_per']] = df.apply(lambda row: characters_per_side(row),axis=1)

# %%
df['penalty'] = df.apply(lambda row: sequance_score(row),axis=1)

# %%
df.head(100)
# Out:
#                    word  length           word_clean  l_count  l_per  r_count  \
# 0       's anderendaags      13        sanderendaags       11     85        2
# 1             's avonds       7              savonds        5     71        2
# 2            's middags       8             smiddags        6     75        2
# 3             's nachts       7              snachts        5     71        2
# 4           's ochtends       9            sochtends        6     67        3
# 5         's-Gravenhage      11          sGravenhage        9     82        2
# 6      's-Hertogenbosch      14       sHertogenbosch        8     57        6
# 7             06-nummer       8             06nummer        3     38        5
# 8            1 aprilgek       9            1aprilgek        5     56        4
# 9           1 aprilgrap      10           1aprilgrap        6     60        4
# 10           1 aprilmop       9            1aprilmop        3     33        6
# 11      5 meiherdenking      14       5meiherdenking        7     50        7
# 12         5 meiviering      11          5meiviering        6     55        5
# 13        8 uurjournaal      12         8uurjournaal        4     33        8
# 14            80-jarige       8             80jarige        4     50        4
# 15             A-biljet       7              Abiljet        3     43        4
# 16                A-bom       4                 Abom        1     25        3
# 17               A-kant       5                Akant        3     60        2
# 18               A-merk       5                Amerk        3     60        2
# 19             A-omroep       7              Aomroep        3     43        4
# 20             A-status       7              Astatus        6     86        1
# 21           A4-formaat       9            A4formaat        7     78        2
# 22      AAW-voorziening      14       AAWvoorziening        8     57        6
# 23         ABC-eilanden      11          ABCeilanden        6     55        5
# 24           ABC-wapens       9            ABCwapens        6     67        3
# 25                 ADHD       4                 ADHD        3     75        1
# 26            ADHD-kind       8             ADHDkind        4     50        4
# 27                 ADSL       4                 ADSL        3     75        1
# 28     ADSL-aansluiting      15      ADSLaansluiting        8     53        7
# 29                 AMvB       4                 AMvB        2     50        2
# ..                  ...     ...                  ...      ...    ...      ...
# 70            Algerijns       9            Algerijns        5     56        4
# 71           Algerijnse      10           Algerijnse        6     60        4
# 72                Allah       5                Allah        2     40        3
# 73        Allerheiligen      13        Allerheiligen        6     46        7
# 74   Allerheiligenvloed      18   Allerheiligenvloed        9     50        9
# 75         Allerhoogste      12         Allerhoogste        7     58        5
# 76          Allerzielen      11          Allerzielen        6     55        5
# 77           Almachtige      10           Almachtige        6     60        4
# 78            Alwetende       9            Alwetende        7     78        2
# 79             Alziende       8             Alziende        5     62        3
# 80                Amati       5                Amati        3     60        2
# 81        Amazonegebied      13        Amazonegebied        8     62        5
# 82             Amazonen       8             Amazonen        4     50        4
# 83             Ambonees       8             Ambonees        4     50        4
# 84    American football      16     Americanfootball        8     50        8
# 85            Amerikaan       9            Amerikaan        5     56        4
# 86           Amerikaans      10           Amerikaans        6     60        4
# 87          Amerikaanse      11          Amerikaanse        7     64        4
# 88            Amsterdam       9            Amsterdam        7     78        2
# 89         Amsterdammer      12         Amsterdammer        9     75        3
# 90           Amsterdams      10           Amsterdams        8     80        2
# 91      Anderlechtenaar      15      Anderlechtenaar       11     73        4
# 92  Anderlechtsupporter      19  Anderlechtsupporter       12     63        7
# 93        Andesgebergte      13        Andesgebergte       11     85        2
# 94              Andorra       7              Andorra        5     71        2
# 95            Andorrees       9            Andorrees        7     78        2
# 96       Andromedanevel      14       Andromedanevel        9     64        5
# 97          Angelsaksen      11          Angelsaksen        7     64        4
# 98        Angelsaksisch      13        Angelsaksisch        8     62        5
# 99     Anglo-Amerikaans      15      AngloAmerikaans        8     53        7
#
#     r_per  penalty
# 0      15        8
# 1      29        4
# 2      25        5
# 3      29        2
# 4      33        2
# 5      18        8
# 6      43        6
# 7      62        4
# 8      44        3
# 9      40        4
# 10     67        5
# 11     50        7
# 12     45        2
# 13     67        5
# 14     50        4
# 15     57        4
# 16     75        2
# 17     40        0
# 18     40        1
# 19     57        1
# 20     14        4
# 21     22        4
# 22     43        7
# 23     45        3
# 24     33        2
# 25     25        1
# 26     50        3
# 27     25        2
# 28     47        6
# 29     50        0
# ..    ...      ...
# 70     44        4
# 71     40        5
# 72     60        1
# 73     54        5
# 74     50        7
# 75     42        7
# 76     45        3
# 77     40        3
# 78     22        4
# 79     38        1
# 80     40        1
# 81     38        6
# 82     50        2
# 83     50        5
# 84     50        4
# 85     44        3
# 86     40        3
# 87     36        4
# 88     22        5
# 89     25        7
# 90     20        5
# 91     27        6
# 92     37       10
# 93     15        8
# 94     29        2
# 95     22        4
# 96     36        6
# 97     36        3
# 98     38        3
# 99     47        4
#
# [100 rows x 8 columns]

# %%
df.to_csv('list.csv')

# %%
![alttext](powerBi.PNG "Dashboard")

# %%
whos function
# Out:
# Variable              Type        Data/Info
# -------------------------------------------
# characters_per_side   function    <function characters_per_side at 0x7fc7902012f0>
# clean_word            function    <function clean_word at 0x7fc790201268>
# cleaning              function    <function cleaning at 0x7fc7903c9268>
# sequanceScore         function    <function sequanceScore at 0x7fc790238378>
# sequance_score        function    <function sequance_score at 0x7fc790201158>
# sideLen               function    <function sideLen at 0x7fc79040fd90>
# test_function         function    <function test_function at 0x7fc79028df28>

# %%
characters_per_side?
